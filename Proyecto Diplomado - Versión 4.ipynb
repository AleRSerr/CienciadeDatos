# %% [markdown]
# ## Proyección de Datos - Aeropuerto de Leipzig (DE)

# %% [markdown]
# ### **Reporte No. 3** - Borrador de Proyecto

# %% [markdown]
# <p><strong>Asesor Principal</strong>: Prof. Álvaro Mauricio Montenegro Díaz, PhD <a>ammontenegrod@unal.edu.co</a> <br>
# <strong>Asesor Suplente</strong>: Prof. Campo Elías Pardo Turriago, <a>cepardot@unal.edu.co</a> <br>
# <strong>Autor</strong>: Alejandro Rios Serrano, <a>oarioss@unal.edu.co</a> </p>

# %% [markdown]
# #### Introduccion

# %% [markdown]
# la recoleccion y analisis de datos en la infraestructura permite una mejor planeación al proyectar futuras ampliaciones y mejoras en la construccion. La infraestructura instalada va copando su capacidad hasta que se hace necesaria una ampliación, nueva construccion o mejora de la capacidad.
#
# La proyección de uso en la infraestructura permite planear las ampliaciones y mejoras futuras con suficienta antelación para planear correctamente, conseguir permisos, desarrollar y ejecutar el proyecto.

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*0o44SgYfO_NgbEbqRICftw.png" width="700" height="700">

# %% [markdown]
#    #### Descripción del Problema

# %% [markdown]
# El aeropuerto de Leipzig ha venido creciendo constantemente desde 1991, posicionandose como el segundo mayor aeropuerto de carga de Alemania detrás de Frankfurt [**Source**: Qualitätsbericht - Luftverkehrsteuer 04/2022](https://www-genesis.destatis.de/genesis/online?operation=abruftabelleBearbeiten&levelindex=1&levelid=1667651441718&auswahloperation=abruftabelleAuspraegungAuswaehlen&auswahlverzeichnis=ordnungsstruktur&auswahlziel=werteabruf&code=46421-0005&auswahltext=&werteabruf=starten&wertauswahl=1695&wertauswahl=1696&wertauswahl=1697&wertauswahl=1698#abreadcrumb).
#
# Durante la pandemia, cayó drásticamente el transporte de carga y especialmente pasajeros. Con análisis de datos se pretende proyectar la recuperación en el transporte de carga y pasajeros, así como las ampliaciones futuras de la capacidad instalada en el aeropuerto de Leipzig (Alemania).
#
#  <img src="http://www.wirtschaftinsachsen.de/wp-content/uploads/2008/10/germanwings_rollbruecke-flughafen-leipzig-halle1.jpg" width="700" height="700">

# %% [markdown]
#    #### Procesamiento ETL

# %% [markdown]
# Se cuenta con los datos de carga y pasajeros mes a mes del aeropuerto de Leipzig entre 2001-2022 *(con fecha de corte a septiembre 2022)*. A partir de los datos se pretende proyectar la recuperación del trafico de carga y pasajeros luego de la pandemia y la fecha estimada de colmación de la capacidad instalada. Se introduce Frankfurt como aeropuerto de control en los datos.

# %% [markdown]
# | **Aeropuerto:** | Frankfurt (FRA) | Leipzig (LEJ) |
# | :---- | :----------- | :------ |
# | **Datos** | pasajeros, , vuelos, carga | pasajeros, vuelos, carga |
# | **Frecuencia** | mensual | mensual |

# %% [markdown]
# **Cantidad de Datos:** 1566 Datos (meses entre 2001-2022)<br>
# **Cantidad de Variables:** 3

# %% [markdown]
# Se realizó la extracción de datos mensual y se organizó en las tres variables de los dos aeropuertos: Leipzig (LEJ) y Frankfurt (FRA).
# *se utiliza la abreviación de codigo IATA*
#
# Los datos se guardaron en un formato .csv y se alojaron localmente (disco D). El cargue de archivos se puede ver a continuación:

# %%
import pandas as pd
filepath=r"D:\Documents\0. PERSONAL\2. Estudio\5. Data Science\Proyecto Diplomado\2022.csv"
df=pd.read_csv(filepath, sep=";",skip_blank_lines=True, header=0, index_col=0,na_filter=False)
df.head(10)
# Out:
#                    LEJ Pasajeros  LEJ Vuelos  LEJ Carga (en Ton)  \
# Fecha
# 2001 - enero              100039        2514                1279
# 2001 - febrero            123024        2500                1282
# 2001 - marzo              139184        2828                1332
# 2001 - abril              168075        2853                1094
# 2001 - mayo               189075        2912                1046
# 2001 - junio              227886        3147                1060
# 2001 - julio              259677        3170                1067
# 2001 - agosto             231281        3152                 983
# 2001 - septiembre         260053        3116                1060
# 2001 - octubre            218845        3038                1132
#
#                    FRA Pasajeros  FRA Vuelos  FRA Carga (en Ton)
# Fecha
# 2001 - enero             3485502       36134              125539
# 2001 - febrero           3331837       33304              134400
# 2001 - marzo             4113299       37997              155509
# 2001 - abril             4161270       37103              133906
# 2001 - mayo              4188493       38321              128859
# 2001 - junio             4543610       38830              133396
# 2001 - julio             4843476       40462              132670
# 2001 - agosto            4815067       39968              128057
# 2001 - septiembre        4410978       38706              130765
# 2001 - octubre           3929095       38637              145423

# %%
df.tail(10)
# Out:
#                    LEJ Pasajeros  LEJ Vuelos  LEJ Carga (en Ton)  \
# Fecha
# 2021 - diciembre           39816        6295              193682
# 2022 - enero               31985        5526              128061
# 2022 - febrero             36692        5321              123232
# 2022 - marzo               63888        6075              133788
# 2022 - abril              117311        5879              125240
# 2022 - mayo               149122        6419              129787
# 2022 - junio              166403        6403              127045
# 2022 - julio              185080        6565              125849
# 2022 - agosto             201995        6567              118327
# 2022 - septiembre         197792        6637              124579
#
#                    FRA Pasajeros  FRA Vuelos  FRA Carga (en Ton)
# Fecha
# 2021 - diciembre         2711316       27476              148925
# 2022 - enero             2203901       24201              171749
# 2022 - febrero           2112961       21848              161795
# 2022 - marzo             2929942       26318              177610
# 2022 - abril             3965858       31740              166023
# 2022 - mayo              4570200       35930              169325
# 2022 - junio             4980579       35261              163917
# 2022 - julio             5013381       33313              157418
# 2022 - agosto            5184080       35252              151582
# 2022 - septiembre        4879956       33529              157961

# %% [markdown]
# Las variables de pasajeros y vuelos vienen expresadas en unidad (número de vuelos, número de pasajeros) y las de carga en peso (toneladas).
#
# Se cuenta entonces con 3 variables de dos aeropuertos y una totalidad de 1560 datos (arriba en dos tablas expresadas).

# %% [markdown]
# #### Descripción de los Datos

# %% [markdown]
# Se realiza la primera descripción estadistica de los datos:

# %%
df.describe().T
# Out:
#                     count          mean           std       min        25%  \
# LEJ Pasajeros       261.0  1.639646e+05  7.114715e+04     502.0   114174.0
# LEJ Vuelos          261.0  4.379966e+03  1.287868e+03    1776.0     3152.0
# LEJ Carga (en Ton)  261.0  5.700616e+04  4.491116e+04     375.0     2068.0
# FRA Pasajeros       261.0  4.391676e+06  1.236314e+06  187346.0  3852431.0
# FRA Vuelos          261.0  3.712972e+04  7.179095e+03    6148.0    35379.0
# FRA Carga (en Ton)  261.0  1.688552e+05  2.008074e+04  115409.0   155631.0
#
#                           50%        75%        max
# LEJ Pasajeros        157708.0   226800.0   309288.0
# LEJ Vuelos             4705.0     5281.0     6794.0
# LEJ Carga (en Ton)    65040.0    92420.0   193682.0
# FRA Pasajeros       4489581.0  5059060.0  6909529.0
# FRA Vuelos            38830.0    41554.0    46598.0
# FRA Carga (en Ton)   173228.0   182699.0   209811.0

# %% [markdown]
# Se crean seguidamente los plots en pandas junto con matplotlib empezando con la importación de las bibliotecas y la generación de los plots:

# %%
import matplotlib as mpl
from math import sqrt
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
import tensorflow as tf
# Out:
# C:\Users\USER\anaconda3\envs\nombre_ambiente\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# El primer plano condensa la totalidad de las variables en un solo plot. Por la gran diferencia en los numeros (miles, cientos de miles y **millones**) el plot no es facilmente legible (sobretodo por el flujo de pasajeros en FRA).
#
# Adicionalmente tengo el problema que no me lee las series de tiempo sino el número de datos:

# %%
df.plot(xlabel="Tiempo",rot=45,figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Tiempo'>

# %% [markdown]
# En este segundo gráfico (más de ejercicio que de utilidad) compare el desarrollo del flujo de pasajeros y el número de vuelos entre 2001 y 2022 (corte a septiembre) agregando un plot secundario en el eje y.

# %%
df["LEJ Pasajeros"].plot(kind="line",
                         grid=True,
                         title="Desarrollo flujo de pasajeros - Aeropuerto de Leipzig entre 2001-2022",
                         ylabel="Pasajeros",
                         xlabel="Tiempo", rot=45,figsize=(16,9))
df["LEJ Vuelos"].plot(secondary_y=True, style="r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Se realiza la graficacion de las tres variables (pasajeros, vuelos y carga) para cara aeropuerto, empezando con LEJ:

# %%
with pd.plotting.plot_params.use("x_compat",True):
    df["LEJ Pasajeros"].plot(color="r",title="Aeropuerto Leipzig (LEJ)", figsize=(16,9))
    df["LEJ Vuelos"].plot(color="g")
    df["LEJ Carga (en Ton)"].plot(color="b")

# %% [markdown]
# Y en este caso con FRA, notando el problema causado por la diferencia entre el gran flujo de pasajeros (rojo) y las otras variables:

# %%
with pd.plotting.plot_params.use("x_compat",True):
    df["FRA Pasajeros"].plot(color="r", title="Aeropuerto Frankfurt (FRA)",figsize=(16,9))
    df["FRA Vuelos"].plot(color="g")
    df["FRA Carga (en Ton)"].plot(color="b")

# %% [markdown]
# Finalmente se realizan subplots con las variables:

# %%
axs=df.plot.area(figsize=(10,10),subplots=True)

# %%
df.plot.area(subplots=True, layout=(2, 3), figsize=(15, 5), rot=45, sharex=False);

# %% [markdown]
# Se extraeran los datos (pasajeros y carga) de los aeropuertos FRA y LEJ de las tablas (estas contienen la totalidad de los aeropuertos en Alemania). Se harán los analisis de los datos y se hará la proxección de crecimiento para los siguientes años hasta encontrar la fecha estimada de recuperación en el transporte y la fecha estimada de colmación de la capacidad.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 2001 - enero to 2022 - septiembre
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LEJ Pasajeros       261 non-null    int64
#  1   LEJ Vuelos          261 non-null    int64
#  2   LEJ Carga (en Ton)  261 non-null    int64
#  3   FRA Pasajeros       261 non-null    int64
#  4   FRA Vuelos          261 non-null    int64
#  5   FRA Carga (en Ton)  261 non-null    int64
# dtypes: int64(6)
# memory usage: 14.3+ KB

# %%
MinMax = df[["LEJ Pasajeros","LEJ Vuelos", "LEJ Carga (en Ton)", "FRA Pasajeros", "FRA Vuelos", "FRA Carga (en Ton)"]].agg(['min','max'])
print (MinMax)
# Out:
#      LEJ Pasajeros  LEJ Vuelos  LEJ Carga (en Ton)  FRA Pasajeros  FRA Vuelos  \
# min            502        1776                 375         187346        6148
# max         309288        6794              193682        6909529       46598
#
#      FRA Carga (en Ton)
# min              115409
# max              209811

# %%
cols=[0]
df_scal=df[df.columns[cols]]
df_scal.head()
# Out:
#                 LEJ Pasajeros
# Fecha
# 2001 - enero           100039
# 2001 - febrero         123024
# 2001 - marzo           139184
# 2001 - abril           168075
# 2001 - mayo            189075

# %%
df_scal.tail()
# Out:
#                    LEJ Pasajeros
# Fecha
# 2022 - mayo               149122
# 2022 - junio              166403
# 2022 - julio              185080
# 2022 - agosto             201995
# 2022 - septiembre         197792

# %%
df_scal.plot.area(subplots=True, rot=45,layout=(2,3), figsize=(15, 6), sharex=False);
plt.show()

# %% [markdown]
# #### Funciones para gráficos*
#
# **información tomada de la lección [pronóstico series temporales](https://www.aprendemachinelearning.com/pronostico-de-series-temporales-con-redes-neuronales-en-python/) del portal "aprende machine learning"*

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
PASOS=12

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values=df_scal
values=values.astype("float32")
scaler=MinMaxScaler(feature_range=(-1,1))
values=df_scal.values.reshape(-1,1)
scaled=scaler.fit_transform(values)
reframed=series_to_supervised(scaled,PASOS,1)
reframed.head()
# Out:
#     var1(t+12)  var1(t+11)  var1(t+10)  var1(t+9)  var1(t+8)  var1(t+7)  \
# 12   -0.355301   -0.206428   -0.101760   0.085367   0.221383   0.472761
# 13   -0.206428   -0.101760    0.085367   0.221383   0.472761   0.678671
# 14   -0.101760    0.085367    0.221383   0.472761   0.678671   0.494750
# 15    0.085367    0.221383    0.472761   0.678671   0.494750   0.681106
# 16    0.221383    0.472761    0.678671   0.494750   0.681106   0.414203
#
#     var1(t+6)  var1(t+5)  var1(t+4)  var1(t+3)  var1(t+2)  var1(t+1)   var1(t)
# 12   0.678671   0.494750   0.681106   0.414203  -0.292196  -0.523521 -0.479827
# 13   0.494750   0.681106   0.414203  -0.292196  -0.523521  -0.479827 -0.321796
# 14   0.681106   0.414203  -0.292196  -0.523521  -0.479827  -0.321796 -0.194251
# 15   0.414203  -0.292196  -0.523521  -0.479827  -0.321796  -0.194251 -0.177689
# 16  -0.292196  -0.523521  -0.479827  -0.321796  -0.194251  -0.177689  0.049989

# %%
reframed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 12 to 260
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   var1(t+12)  249 non-null    float64
#  1   var1(t+11)  249 non-null    float64
#  2   var1(t+10)  249 non-null    float64
#  3   var1(t+9)   249 non-null    float64
#  4   var1(t+8)   249 non-null    float64
#  5   var1(t+7)   249 non-null    float64
#  6   var1(t+6)   249 non-null    float64
#  7   var1(t+5)   249 non-null    float64
#  8   var1(t+4)   249 non-null    float64
#  9   var1(t+3)   249 non-null    float64
#  10  var1(t+2)   249 non-null    float64
#  11  var1(t+1)   249 non-null    float64
#  12  var1(t)     249 non-null    float64
# dtypes: float64(13)
# memory usage: 27.2 KB

# %%
reframed.plot(xlabel="Datos",rot=45,figsize=(16,9),legend=False)
# Out:
# <AxesSubplot:xlabel='Datos'>

# %%
#split into train and test sets
values=reframed.values
n_train_months=261-(24+PASOS)
train=values[:n_train_months,:]
test=values[n_train_months:,:]
#split into input and outputs
x_train,y_train=train[:,:-1], train[:,-1]
x_val,y_val=test[:,:-1],test[:,-1]
#reshape input to be 3D [samples, timesteps,features]
x_train=x_train.reshape((x_train.shape[0],1,x_train.shape[1]))
x_val=x_val.reshape((x_val.shape[0],1,x_val.shape[1]))
print(x_train.shape,y_train.shape,x_val.shape,y_val.shape)
# Out:
# (225, 1, 12) (225,) (24, 1, 12) (24,)

# %%
def crear_modelo():
    model=Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation="tanh"))
    model.add(Flatten())
    model.add(Dense(1,activation="tanh"))
    model.compile(loss="mean_absolute_error",optimizer="Adam",metrics=["mse"])
    model.summary()
    return model

# %%
#Entrenamiento y Resultados
EPOCHS=30
model=crear_modelo()
history=model.fit(x_train,y_train,epochs=EPOCHS, validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1, 12)             156
#
#  flatten_2 (Flatten)         (None, 12)                0
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 169
# Trainable params: 169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 3s 36ms/step - loss: 0.3519 - mse: 0.2163 - val_loss: 0.6299 - val_mse: 0.5450
# Epoch 2/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2480 - mse: 0.1172 - val_loss: 0.5471 - val_mse: 0.4407
# Epoch 3/30
# 19/19 [==============================] - 0s 12ms/step - loss: 0.1870 - mse: 0.0769 - val_loss: 0.4616 - val_mse: 0.3382
# Epoch 4/30
# 19/19 [==============================] - 0s 12ms/step - loss: 0.1609 - mse: 0.0603 - val_loss: 0.4005 - val_mse: 0.2675
# Epoch 5/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1524 - mse: 0.0561 - val_loss: 0.3694 - val_mse: 0.2172
# Epoch 6/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1441 - mse: 0.0531 - val_loss: 0.3588 - val_mse: 0.1893
# Epoch 7/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1381 - mse: 0.0518 - val_loss: 0.3517 - val_mse: 0.1748
# Epoch 8/30
# 19/19 [==============================] - 1s 28ms/step - loss: 0.1340 - mse: 0.0498 - val_loss: 0.3494 - val_mse: 0.1712
# Epoch 9/30
# 19/19 [==============================] - 0s 17ms/step - loss: 0.1318 - mse: 0.0490 - val_loss: 0.3493 - val_mse: 0.1692
# Epoch 10/30
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1301 - mse: 0.0483 - val_loss: 0.3500 - val_mse: 0.1688
# Epoch 11/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1284 - mse: 0.0476 - val_loss: 0.3502 - val_mse: 0.1694
# Epoch 12/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1278 - mse: 0.0484 - val_loss: 0.3513 - val_mse: 0.1710
# Epoch 13/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1271 - mse: 0.0481 - val_loss: 0.3516 - val_mse: 0.1718
# Epoch 14/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1274 - mse: 0.0466 - val_loss: 0.3502 - val_mse: 0.1702
# Epoch 15/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1250 - mse: 0.0471 - val_loss: 0.3514 - val_mse: 0.1715
# Epoch 16/30
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1248 - mse: 0.0470 - val_loss: 0.3524 - val_mse: 0.1725
# Epoch 17/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1238 - mse: 0.0464 - val_loss: 0.3519 - val_mse: 0.1725
# Epoch 18/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1237 - mse: 0.0466 - val_loss: 0.3510 - val_mse: 0.1719
# Epoch 19/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1226 - mse: 0.0458 - val_loss: 0.3517 - val_mse: 0.1724
# Epoch 20/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1229 - mse: 0.0459 - val_loss: 0.3520 - val_mse: 0.1730
# Epoch 21/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1226 - mse: 0.0456 - val_loss: 0.3534 - val_mse: 0.1744
# Epoch 22/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1216 - mse: 0.0460 - val_loss: 0.3526 - val_mse: 0.1750
# Epoch 23/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1215 - mse: 0.0455 - val_loss: 0.3524 - val_mse: 0.1742
# Epoch 24/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1208 - mse: 0.0437 - val_loss: 0.3531 - val_mse: 0.1744
# Epoch 25/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1196 - mse: 0.0443 - val_loss: 0.3523 - val_mse: 0.1741
# Epoch 26/30
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1190 - mse: 0.0443 - val_loss: 0.3522 - val_mse: 0.1752
# Epoch 27/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1201 - mse: 0.0451 - val_loss: 0.3534 - val_mse: 0.1757
# Epoch 28/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1189 - mse: 0.0440 - val_loss: 0.3528 - val_mse: 0.1751
# Epoch 29/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1183 - mse: 0.0437 - val_loss: 0.3526 - val_mse: 0.1765
# Epoch 30/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1170 - mse: 0.0438 - val_loss: 0.3541 - val_mse: 0.1757

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c="g")
plt.scatter(range(len(results)),results,c="r")
plt.title("Validación")
plt.show()
# Out:
# 1/1 [==============================] - 0s 225ms/step

# %%
plt.plot(history.history['loss'])
plt.title('loss')
plt.plot(history.history['val_loss'])
plt.title('validate loss')
plt.show()

# %%
octubre2022=df_scal["2019 - octubre":"2022 - septiembre"]
octubre2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 2019 - octubre to 2022 - septiembre
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LEJ Pasajeros  36 non-null     int64
# dtypes: int64(1)
# memory usage: 576.0+ bytes

# %%
PASOS=12

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values=octubre2022.values
values=values.astype("float32")
values=values.reshape(-1,1)
scaled=scaler.fit_transform(values)
reframed=series_to_supervised(scaled,PASOS,1)
reframed.drop(reframed.columns[[12]],axis=1,inplace=True)
reframed.head()
# Out:
#     var1(t+12)  var1(t+11)  var1(t+10)  var1(t+9)  var1(t+8)  var1(t+7)  \
# 12    1.000000    0.018220   -0.176161  -0.214634  -0.128438  -0.544254
# 13    0.018220   -0.176161   -0.214634  -0.128438  -0.544254  -1.000000
# 14   -0.176161   -0.214634   -0.128438  -0.544254  -1.000000  -0.998491
# 15   -0.214634   -0.128438   -0.544254  -1.000000  -0.998491  -0.994585
# 16   -0.128438   -0.544254   -1.000000  -0.998491  -0.994585  -0.761822
#
#     var1(t+6)  var1(t+5)  var1(t+4)  var1(t+3)  var1(t+2)  var1(t+1)
# 12  -1.000000  -0.998491  -0.994585  -0.761822  -0.633785  -0.689325
# 13  -0.998491  -0.994585  -0.761822  -0.633785  -0.689325  -0.710388
# 14  -0.994585  -0.761822  -0.633785  -0.689325  -0.710388  -0.960847
# 15  -0.761822  -0.633785  -0.689325  -0.710388  -0.960847  -0.992720
# 16  -0.633785  -0.689325  -0.710388  -0.960847  -0.992720  -0.998128

# %%
reframed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 12 to 35
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   var1(t+12)  24 non-null     float32
#  1   var1(t+11)  24 non-null     float32
#  2   var1(t+10)  24 non-null     float32
#  3   var1(t+9)   24 non-null     float32
#  4   var1(t+8)   24 non-null     float32
#  5   var1(t+7)   24 non-null     float32
#  6   var1(t+6)   24 non-null     float32
#  7   var1(t+5)   24 non-null     float32
#  8   var1(t+4)   24 non-null     float32
#  9   var1(t+3)   24 non-null     float32
#  10  var1(t+2)   24 non-null     float32
#  11  var1(t+1)   24 non-null     float32
# dtypes: float32(12)
# memory usage: 1.3 KB

# %%
values=reframed.values
x_test=values[:,:]
x_test=x_test.reshape((x_test.shape[0],1,x_test.shape[1]))
print (x_test.shape)
x_test
# Out:
# (24, 1, 12)
# array([[[ 0.9999999 ,  0.01821971, -0.17616087, -0.21463412,
#          -0.12843847, -0.54425395, -1.        , -0.99849087,
#          -0.9945852 , -0.7618221 , -0.63378525, -0.68932533]],
#
#        [[ 0.01821971, -0.17616087, -0.21463412, -0.12843847,
#          -0.54425395, -1.        , -0.99849087, -0.9945852 ,
#          -0.7618221 , -0.63378525, -0.68932533, -0.7103884 ]],
#
#        [[-0.17616087, -0.21463412, -0.12843847, -0.54425395,
#          -1.        , -0.99849087, -0.9945852 , -0.7618221 ,
#          -0.63378525, -0.68932533, -0.7103884 , -0.96084666]],
#
#        [[-0.21463412, -0.12843847, -0.54425395, -1.        ,
#          -0.99849087, -0.9945852 , -0.7618221 , -0.63378525,
#          -0.68932533, -0.7103884 , -0.96084666, -0.9927199 ]],
#
#        [[-0.12843847, -0.54425395, -1.        , -0.99849087,
#          -0.9945852 , -0.7618221 , -0.63378525, -0.68932533,
#          -0.7103884 , -0.96084666, -0.9927199 , -0.9981281 ]],
#
#        [[-0.54425395, -1.        , -0.99849087, -0.9945852 ,
#          -0.7618221 , -0.63378525, -0.68932533, -0.7103884 ,
#          -0.96084666, -0.9927199 , -0.9981281 , -0.99797267]],
#
#        [[-1.        , -0.99849087, -0.9945852 , -0.7618221 ,
#          -0.63378525, -0.68932533, -0.7103884 , -0.96084666,
#          -0.9927199 , -0.9981281 , -0.99797267, -0.98234373]],
#
#        [[-0.99849087, -0.9945852 , -0.7618221 , -0.63378525,
#          -0.68932533, -0.7103884 , -0.96084666, -0.9927199 ,
#          -0.9981281 , -0.99797267, -0.98234373, -0.96264076]],
#
#        [[-0.9945852 , -0.7618221 , -0.63378525, -0.68932533,
#          -0.7103884 , -0.96084666, -0.9927199 , -0.9981281 ,
#          -0.99797267, -0.98234373, -0.96264076, -0.9421541 ]],
#
#        [[-0.7618221 , -0.63378525, -0.68932533, -0.7103884 ,
#          -0.96084666, -0.9927199 , -0.9981281 , -0.99797267,
#          -0.98234373, -0.96264076, -0.9421541 , -0.7744392 ]],
#
#        [[-0.63378525, -0.68932533, -0.7103884 , -0.96084666,
#          -0.9927199 , -0.9981281 , -0.99797267, -0.98234373,
#          -0.96264076, -0.9421541 , -0.7744392 , -0.43062186]],
#
#        [[-0.68932533, -0.7103884 , -0.96084666, -0.9927199 ,
#          -0.9981281 , -0.99797267, -0.98234373, -0.96264076,
#          -0.9421541 , -0.7744392 , -0.43062186, -0.192716  ]],
#
#        [[-0.7103884 , -0.96084666, -0.9927199 , -0.9981281 ,
#          -0.99797267, -0.98234373, -0.96264076, -0.9421541 ,
#          -0.7744392 , -0.43062186, -0.192716  , -0.18011183]],
#
#        [[-0.96084666, -0.9927199 , -0.9981281 , -0.99797267,
#          -0.98234373, -0.96264076, -0.9421541 , -0.7744392 ,
#          -0.43062186, -0.192716  , -0.18011183,  0.01851761]],
#
#        [[-0.9927199 , -0.9981281 , -0.99797267, -0.98234373,
#          -0.96264076, -0.9421541 , -0.7744392 , -0.43062186,
#          -0.192716  , -0.18011183,  0.01851761, -0.5551223 ]],
#
#        [[-0.9981281 , -0.99797267, -0.98234373, -0.96264076,
#          -0.9421541 , -0.7744392 , -0.43062186, -0.192716  ,
#          -0.18011183,  0.01851761, -0.5551223 , -0.74536407]],
#
#        [[-0.99797267, -0.98234373, -0.96264076, -0.9421541 ,
#          -0.7744392 , -0.43062186, -0.192716  , -0.18011183,
#           0.01851761, -0.5551223 , -0.74536407, -0.7960853 ]],
#
#        [[-0.98234373, -0.96264076, -0.9421541 , -0.7744392 ,
#          -0.43062186, -0.192716  , -0.18011183,  0.01851761,
#          -0.5551223 , -0.74536407, -0.7960853 , -0.7655982 ]],
#
#        [[-0.96264076, -0.9421541 , -0.7744392 , -0.43062186,
#          -0.192716  , -0.18011183,  0.01851761, -0.5551223 ,
#          -0.74536407, -0.7960853 , -0.7655982 , -0.5894503 ]],
#
#        [[-0.9421541 , -0.7744392 , -0.43062186, -0.192716  ,
#          -0.18011183,  0.01851761, -0.5551223 , -0.74536407,
#          -0.7960853 , -0.7655982 , -0.5894503 , -0.24343073]],
#
#        [[-0.7744392 , -0.43062186, -0.192716  , -0.18011183,
#           0.01851761, -0.5551223 , -0.74536407, -0.7960853 ,
#          -0.7655982 , -0.5894503 , -0.24343073, -0.0373916 ]],
#
#        [[-0.43062186, -0.192716  , -0.18011183,  0.01851761,
#          -0.5551223 , -0.74536407, -0.7960853 , -0.7655982 ,
#          -0.5894503 , -0.24343073, -0.0373916 ,  0.07453704]],
#
#        [[-0.192716  , -0.18011183,  0.01851761, -0.5551223 ,
#          -0.74536407, -0.7960853 , -0.7655982 , -0.5894503 ,
#          -0.24343073, -0.0373916 ,  0.07453704,  0.19550753]],
#
#        [[-0.18011183,  0.01851761, -0.5551223 , -0.74536407,
#          -0.7960853 , -0.7655982 , -0.5894503 , -0.24343073,
#          -0.0373916 ,  0.07453704,  0.19550753,  0.30506563]]],
#       dtype=float32)

# %%
def agregarNuevoMes(x_test,nuevoMes):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i]=x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoMes
    return x_test

results=[]
for i in range (3):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test=agregarNuevoMes(x_test,parcial[0])
# Out:
# 1/1 [==============================] - 0s 73ms/step
# [[[ 0.9999999   0.01821971 -0.17616087 -0.21463412 -0.12843847
#    -0.54425395 -1.         -0.99849087 -0.9945852  -0.7618221
#    -0.63378525 -0.68932533]]
#
#  [[ 0.01821971 -0.17616087 -0.21463412 -0.12843847 -0.54425395
#    -1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884 ]]
#
#  [[-0.17616087 -0.21463412 -0.12843847 -0.54425395 -1.
#    -0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666]]
#
#  [[-0.21463412 -0.12843847 -0.54425395 -1.         -0.99849087
#    -0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199 ]]
#
#  [[-0.12843847 -0.54425395 -1.         -0.99849087 -0.9945852
#    -0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281 ]]
#
#  [[-0.54425395 -1.         -0.99849087 -0.9945852  -0.7618221
#    -0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267]]
#
#  [[-1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373]]
#
#  [[-0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076]]
#
#  [[-0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541 ]]
#
#  [[-0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392 ]]
#
#  [[-0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186]]
#
#  [[-0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716  ]]
#
#  [[-0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183]]
#
#  [[-0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761]]
#
#  [[-0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223 ]]
#
#  [[-0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407]]
#
#  [[-0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853 ]]
#
#  [[-0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982 ]]
#
#  [[-0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503 ]]
#
#  [[-0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223  -0.74536407 -0.7960853  -0.7655982
#    -0.5894503  -0.24343073]]
#
#  [[-0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407 -0.7960853  -0.7655982  -0.5894503
#    -0.24343073 -0.0373916 ]]
#
#  [[-0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853  -0.7655982  -0.5894503  -0.24343073
#    -0.0373916   0.07453704]]
#
#  [[-0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982  -0.5894503  -0.24343073 -0.0373916
#     0.07453704  0.19550753]]
#
#  [[-0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503  -0.24343073 -0.0373916   0.07453704
#     0.19550753  0.30506563]]]
# 1/1 [==============================] - 0s 42ms/step
# [[[ 0.01821971 -0.17616087 -0.21463412 -0.12843847 -0.54425395
#    -1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533  0.28560594]]
#
#  [[ 0.01821971 -0.17616087 -0.21463412 -0.12843847 -0.54425395
#    -1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884 ]]
#
#  [[-0.17616087 -0.21463412 -0.12843847 -0.54425395 -1.
#    -0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666]]
#
#  [[-0.21463412 -0.12843847 -0.54425395 -1.         -0.99849087
#    -0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199 ]]
#
#  [[-0.12843847 -0.54425395 -1.         -0.99849087 -0.9945852
#    -0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281 ]]
#
#  [[-0.54425395 -1.         -0.99849087 -0.9945852  -0.7618221
#    -0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267]]
#
#  [[-1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373]]
#
#  [[-0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076]]
#
#  [[-0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541 ]]
#
#  [[-0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392 ]]
#
#  [[-0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186]]
#
#  [[-0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716  ]]
#
#  [[-0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183]]
#
#  [[-0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761]]
#
#  [[-0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223 ]]
#
#  [[-0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407]]
#
#  [[-0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853 ]]
#
#  [[-0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982 ]]
#
#  [[-0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503 ]]
#
#  [[-0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223  -0.74536407 -0.7960853  -0.7655982
#    -0.5894503  -0.24343073]]
#
#  [[-0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407 -0.7960853  -0.7655982  -0.5894503
#    -0.24343073 -0.0373916 ]]
#
#  [[-0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853  -0.7655982  -0.5894503  -0.24343073
#    -0.0373916   0.07453704]]
#
#  [[-0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982  -0.5894503  -0.24343073 -0.0373916
#     0.07453704  0.19550753]]
#
#  [[-0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503  -0.24343073 -0.0373916   0.07453704
#     0.19550753  0.30506563]]]
# 1/1 [==============================] - 0s 42ms/step
# [[[-0.17616087 -0.21463412 -0.12843847 -0.54425395 -1.
#    -0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#     0.28560594  0.13776791]]
#
#  [[ 0.01821971 -0.17616087 -0.21463412 -0.12843847 -0.54425395
#    -1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884 ]]
#
#  [[-0.17616087 -0.21463412 -0.12843847 -0.54425395 -1.
#    -0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666]]
#
#  [[-0.21463412 -0.12843847 -0.54425395 -1.         -0.99849087
#    -0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199 ]]
#
#  [[-0.12843847 -0.54425395 -1.         -0.99849087 -0.9945852
#    -0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281 ]]
#
#  [[-0.54425395 -1.         -0.99849087 -0.9945852  -0.7618221
#    -0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267]]
#
#  [[-1.         -0.99849087 -0.9945852  -0.7618221  -0.63378525
#    -0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373]]
#
#  [[-0.99849087 -0.9945852  -0.7618221  -0.63378525 -0.68932533
#    -0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076]]
#
#  [[-0.9945852  -0.7618221  -0.63378525 -0.68932533 -0.7103884
#    -0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541 ]]
#
#  [[-0.7618221  -0.63378525 -0.68932533 -0.7103884  -0.96084666
#    -0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392 ]]
#
#  [[-0.63378525 -0.68932533 -0.7103884  -0.96084666 -0.9927199
#    -0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186]]
#
#  [[-0.68932533 -0.7103884  -0.96084666 -0.9927199  -0.9981281
#    -0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716  ]]
#
#  [[-0.7103884  -0.96084666 -0.9927199  -0.9981281  -0.99797267
#    -0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183]]
#
#  [[-0.96084666 -0.9927199  -0.9981281  -0.99797267 -0.98234373
#    -0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761]]
#
#  [[-0.9927199  -0.9981281  -0.99797267 -0.98234373 -0.96264076
#    -0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223 ]]
#
#  [[-0.9981281  -0.99797267 -0.98234373 -0.96264076 -0.9421541
#    -0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407]]
#
#  [[-0.99797267 -0.98234373 -0.96264076 -0.9421541  -0.7744392
#    -0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853 ]]
#
#  [[-0.98234373 -0.96264076 -0.9421541  -0.7744392  -0.43062186
#    -0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982 ]]
#
#  [[-0.96264076 -0.9421541  -0.7744392  -0.43062186 -0.192716
#    -0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503 ]]
#
#  [[-0.9421541  -0.7744392  -0.43062186 -0.192716   -0.18011183
#     0.01851761 -0.5551223  -0.74536407 -0.7960853  -0.7655982
#    -0.5894503  -0.24343073]]
#
#  [[-0.7744392  -0.43062186 -0.192716   -0.18011183  0.01851761
#    -0.5551223  -0.74536407 -0.7960853  -0.7655982  -0.5894503
#    -0.24343073 -0.0373916 ]]
#
#  [[-0.43062186 -0.192716   -0.18011183  0.01851761 -0.5551223
#    -0.74536407 -0.7960853  -0.7655982  -0.5894503  -0.24343073
#    -0.0373916   0.07453704]]
#
#  [[-0.192716   -0.18011183  0.01851761 -0.5551223  -0.74536407
#    -0.7960853  -0.7655982  -0.5894503  -0.24343073 -0.0373916
#     0.07453704  0.19550753]]
#
#  [[-0.18011183  0.01851761 -0.5551223  -0.74536407 -0.7960853
#    -0.7655982  -0.5894503  -0.24343073 -0.0373916   0.07453704
#     0.19550753  0.30506563]]]

# %%
adimen=[x for x in results]
inverted=scaler.inverse_transform(adimen)
inverted
# Out:
# array([[198990.56064723],
#        [176165.40372438],
#        [110417.26676919]])

# %%
prediccion3M=pd.DataFrame(inverted)
prediccion3M.columns=["LEJ Pasajeros"]
prediccion3M.plot(grid=True,
                  title="Pronostico 3 Meses",
                         ylabel="Pasajeros",
                         xlabel="Tiempo")
# Out:
# <AxesSubplot:title={'center':'Pronostico 3 Meses'}, xlabel='Tiempo', ylabel='Pasajeros'>

# %%
prediccion3M.to_csv("pronostico_LEJ.csv")

# %%
df_3=pd.read_csv("pronostico_LEJ.csv",skip_blank_lines=True, header=0, index_col=0,na_filter=False)
df_3.head()
# Out:
#    LEJ Pasajeros
# 0  198990.560647
# 1  176165.403724
# 2  110417.266769

# %%
proyeccion_LEJ=pd.concat([df,df_3])

# %%
display(proyeccion_LEJ)
# Out:
#                    LEJ Pasajeros  LEJ Vuelos  LEJ Carga (en Ton)  \
# 2001 - enero       100039.000000      2514.0              1279.0
# 2001 - febrero     123024.000000      2500.0              1282.0
# 2001 - marzo       139184.000000      2828.0              1332.0
# 2001 - abril       168075.000000      2853.0              1094.0
# 2001 - mayo        189075.000000      2912.0              1046.0
# ...                          ...         ...                 ...
# 2022 - agosto      201995.000000      6567.0            118327.0
# 2022 - septiembre  197792.000000      6637.0            124579.0
# 0                  198990.560647         NaN                 NaN
# 1                  176165.403724         NaN                 NaN
# 2                  110417.266769         NaN                 NaN
#
#                    FRA Pasajeros  FRA Vuelos  FRA Carga (en Ton)
# 2001 - enero           3485502.0     36134.0            125539.0
# 2001 - febrero         3331837.0     33304.0            134400.0
# 2001 - marzo           4113299.0     37997.0            155509.0
# 2001 - abril           4161270.0     37103.0            133906.0
# 2001 - mayo            4188493.0     38321.0            128859.0
# ...                          ...         ...                 ...
# 2022 - agosto          5184080.0     35252.0            151582.0
# 2022 - septiembre      4879956.0     33529.0            157961.0
# 0                            NaN         NaN                 NaN
# 1                            NaN         NaN                 NaN
# 2                            NaN         NaN                 NaN
#
# [264 rows x 6 columns]

# %%
data_end=proyeccion_LEJ.tail()
for row in data_end.index:
    print(row,end=" ")
# Out:
# 2022 - agosto 2022 - septiembre 0 1 2

# %%
ax=proyeccion_LEJ["LEJ Pasajeros"].plot(kind="line",
                         grid=True,style="r",rot=45,
                         title="Aeropuerto de Leipzig - Proyeccion a 3 meses",
                         ylabel="Pasajeros",
                         xlabel="Tiempo", figsize=(16,9))
df["LEJ Pasajeros"].plot(secondary_y=True, style="b")
# Out:
# <AxesSubplot:>

# %%
fig=ax.get_figure()
fig.savefig(r"D:\Documents\0. PERSONAL\2. Estudio\5. Data Science\Proyecto Diplomado\LEJ-3Meses.png")

# %% [markdown]
# #### se toma el mismo procedimiento para FRA - Pasajeros

# %%
cols=[3]
df_FRA=df[df.columns[cols]]
df_FRA.head()
# Out:
#                 FRA Pasajeros
# Fecha
# 2001 - enero          3485502
# 2001 - febrero        3331837
# 2001 - marzo          4113299
# 2001 - abril          4161270
# 2001 - mayo           4188493

# %%
df_FRA.plot.area(subplots=True, rot=45,layout=(2,3), figsize=(15, 6), sharex=False);
plt.show()

# %%
octubre2022_FRA=df_FRA["2019 - octubre":"2022 - septiembre"]
octubre2022_FRA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 2019 - octubre to 2022 - septiembre
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FRA Pasajeros  36 non-null     int64
# dtypes: int64(1)
# memory usage: 576.0+ bytes

# %%
#se hace lo mismo pero redefiniendo las nuevas variables (o al menos así lo expreso yo)
values=octubre2022_FRA.values
values=values.astype("float32")
values=values.reshape(-1,1)
scaled=scaler.fit_transform(values)
reframed_FRA=series_to_supervised(scaled,PASOS,1)
reframed_FRA.drop(reframed_FRA.columns[[12]],axis=1,inplace=True)
reframed_FRA.head()
# Out:
#     var1(t+12)  var1(t+11)  var1(t+10)  var1(t+9)  var1(t+8)  var1(t+7)  \
# 12    1.000000    0.561354    0.497808   0.418120   0.339594  -0.379958
# 13    0.561354    0.497808    0.418120   0.339594  -0.379958  -1.000000
# 14    0.497808    0.418120    0.339594  -0.379958  -1.000000  -0.972848
# 15    0.418120    0.339594   -0.379958  -1.000000  -0.972848  -0.868090
# 16    0.339594   -0.379958   -1.000000  -0.972848  -0.868090  -0.637797
#
#     var1(t+6)  var1(t+5)  var1(t+4)  var1(t+3)  var1(t+2)  var1(t+1)
# 12  -1.000000  -0.972848  -0.868090  -0.637797  -0.575989  -0.692530
# 13  -0.972848  -0.868090  -0.637797  -0.575989  -0.692530  -0.718604
# 14  -0.868090  -0.637797  -0.575989  -0.692530  -0.718604  -0.850321
# 15  -0.637797  -0.575989  -0.692530  -0.718604  -0.850321  -0.775097
# 16  -0.575989  -0.692530  -0.718604  -0.850321  -0.775097  -0.777696

# %%
values=reframed_FRA.values
x_test=values[:,:]
x_test=x_test.reshape((x_test.shape[0],1,x_test.shape[1]))
print (x_test.shape)
x_test
# Out:
# (24, 1, 12)
# array([[[ 0.29477447, -0.11432439, -0.6187035 , -0.60924554,
#          -0.6267087 , -0.6158963 , -0.5052558 , -0.43507794,
#           0.23453276,  0.50739926,  0.38340738,  0.25201595]],
#
#        [[ 0.5613537 ,  0.4978075 ,  0.41811967,  0.33959353,
#          -0.3799578 , -1.        , -0.9728484 , -0.8680903 ,
#          -0.6377969 , -0.57598907, -0.69253016, -0.7186036 ]],
#
#        [[ 0.4978075 ,  0.41811967,  0.33959353, -0.3799578 ,
#          -1.        , -0.9728484 , -0.8680903 , -0.6377969 ,
#          -0.57598907, -0.69253016, -0.7186036 , -0.8503211 ]],
#
#        [[ 0.41811967,  0.33959353, -0.3799578 , -1.        ,
#          -0.9728484 , -0.8680903 , -0.6377969 , -0.57598907,
#          -0.69253016, -0.7186036 , -0.8503211 , -0.7750968 ]],
#
#        [[ 0.33959353, -0.3799578 , -1.        , -0.9728484 ,
#          -0.8680903 , -0.6377969 , -0.57598907, -0.69253016,
#          -0.7186036 , -0.8503211 , -0.7750968 , -0.77769625]],
#
#        [[-0.3799578 , -1.        , -0.9728484 , -0.8680903 ,
#          -0.6377969 , -0.57598907, -0.69253016, -0.7186036 ,
#          -0.8503211 , -0.7750968 , -0.77769625, -0.8419546 ]],
#
#        [[-1.        , -0.9728484 , -0.8680903 , -0.6377969 ,
#          -0.57598907, -0.69253016, -0.7186036 , -0.8503211 ,
#          -0.7750968 , -0.77769625, -0.8419546 , -0.7639872 ]],
#
#        [[-0.9728484 , -0.8680903 , -0.6377969 , -0.57598907,
#          -0.69253016, -0.7186036 , -0.8503211 , -0.7750968 ,
#          -0.77769625, -0.8419546 , -0.7639872 , -0.7451941 ]],
#
#        [[-0.8680903 , -0.6377969 , -0.57598907, -0.69253016,
#          -0.7186036 , -0.8503211 , -0.7750968 , -0.77769625,
#          -0.8419546 , -0.7639872 , -0.7451941 , -0.6609215 ]],
#
#        [[-0.6377969 , -0.57598907, -0.69253016, -0.7186036 ,
#          -0.8503211 , -0.7750968 , -0.77769625, -0.8419546 ,
#          -0.7639872 , -0.7451941 , -0.6609215 , -0.49108934]],
#
#        [[-0.57598907, -0.69253016, -0.7186036 , -0.8503211 ,
#          -0.7750968 , -0.77769625, -0.8419546 , -0.7639872 ,
#          -0.7451941 , -0.6609215 , -0.49108934, -0.1488043 ]],
#
#        [[-0.69253016, -0.7186036 , -0.8503211 , -0.7750968 ,
#          -0.77769625, -0.8419546 , -0.7639872 , -0.7451941 ,
#          -0.6609215 , -0.49108934, -0.1488043 ,  0.01781046]],
#
#        [[-0.7186036 , -0.8503211 , -0.7750968 , -0.77769625,
#          -0.8419546 , -0.7639872 , -0.7451941 , -0.6609215 ,
#          -0.49108934, -0.1488043 ,  0.01781046, -0.0717544 ]],
#
#        [[-0.8503211 , -0.7750968 , -0.77769625, -0.8419546 ,
#          -0.7639872 , -0.7451941 , -0.6609215 , -0.49108934,
#          -0.1488043 ,  0.01781046, -0.0717544 ,  0.02775085]],
#
#        [[-0.7750968 , -0.77769625, -0.8419546 , -0.7639872 ,
#          -0.7451941 , -0.6609215 , -0.49108934, -0.1488043 ,
#           0.01781046, -0.0717544 ,  0.02775085, -0.13284272]],
#
#        [[-0.77769625, -0.8419546 , -0.7639872 , -0.7451941 ,
#          -0.6609215 , -0.49108934, -0.1488043 ,  0.01781046,
#          -0.0717544 ,  0.02775085, -0.13284272, -0.19108349]],
#
#        [[-0.8419546 , -0.7639872 , -0.7451941 , -0.6609215 ,
#          -0.49108934, -0.1488043 ,  0.01781046, -0.0717544 ,
#           0.02775085, -0.13284272, -0.19108349, -0.35370678]],
#
#        [[-0.7639872 , -0.7451941 , -0.6609215 , -0.49108934,
#          -0.1488043 ,  0.01781046, -0.0717544 ,  0.02775085,
#          -0.13284272, -0.19108349, -0.35370678, -0.3828525 ]],
#
#        [[-0.7451941 , -0.6609215 , -0.49108934, -0.1488043 ,
#           0.01781046, -0.0717544 ,  0.02775085, -0.13284272,
#          -0.19108349, -0.35370678, -0.3828525 , -0.12101525]],
#
#        [[-0.6609215 , -0.49108934, -0.1488043 ,  0.01781046,
#          -0.0717544 ,  0.02775085, -0.13284272, -0.19108349,
#          -0.35370678, -0.3828525 , -0.12101525,  0.21098936]],
#
#        [[-0.49108934, -0.1488043 ,  0.01781046, -0.0717544 ,
#           0.02775085, -0.13284272, -0.19108349, -0.35370678,
#          -0.3828525 , -0.12101525,  0.21098936,  0.40467715]],
#
#        [[-0.1488043 ,  0.01781046, -0.0717544 ,  0.02775085,
#          -0.13284272, -0.19108349, -0.35370678, -0.3828525 ,
#          -0.12101525,  0.21098936,  0.40467715,  0.536201  ]],
#
#        [[ 0.01781046, -0.0717544 ,  0.02775085, -0.13284272,
#          -0.19108349, -0.35370678, -0.3828525 , -0.12101525,
#           0.21098936,  0.40467715,  0.536201  ,  0.5467138 ]],
#
#        [[-0.0717544 ,  0.02775085, -0.13284272, -0.19108349,
#          -0.35370678, -0.3828525 , -0.12101525,  0.21098936,
#           0.40467715,  0.536201  ,  0.5467138 ,  0.60142183]]],
#       dtype=float32)

# %%
def agregarNuevoMes(x_test,nuevoMes):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i]=x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoMes
    return x_test

results=[]
for i in range (3):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test=agregarNuevoMes(x_test,parcial[0])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[[ 0.29477447 -0.11432439 -0.6187035  -0.60924554 -0.6267087
#    -0.6158963  -0.5052558  -0.43507794  0.23453276  0.50739926
#     0.38340738  0.25201595]]
#
#  [[ 0.5613537   0.4978075   0.41811967  0.33959353 -0.3799578
#    -1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036 ]]
#
#  [[ 0.4978075   0.41811967  0.33959353 -0.3799578  -1.
#    -0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211 ]]
#
#  [[ 0.41811967  0.33959353 -0.3799578  -1.         -0.9728484
#    -0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968 ]]
#
#  [[ 0.33959353 -0.3799578  -1.         -0.9728484  -0.8680903
#    -0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625]]
#
#  [[-0.3799578  -1.         -0.9728484  -0.8680903  -0.6377969
#    -0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546 ]]
#
#  [[-1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872 ]]
#
#  [[-0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941 ]]
#
#  [[-0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215 ]]
#
#  [[-0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934]]
#
#  [[-0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043 ]]
#
#  [[-0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046]]
#
#  [[-0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544 ]]
#
#  [[-0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085]]
#
#  [[-0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272]]
#
#  [[-0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349]]
#
#  [[-0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678]]
#
#  [[-0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525 ]]
#
#  [[-0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525]]
#
#  [[-0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272 -0.19108349 -0.35370678 -0.3828525
#    -0.12101525  0.21098936]]
#
#  [[-0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349 -0.35370678 -0.3828525  -0.12101525
#     0.21098936  0.40467715]]
#
#  [[-0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678 -0.3828525  -0.12101525  0.21098936
#     0.40467715  0.536201  ]]
#
#  [[ 0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525  -0.12101525  0.21098936  0.40467715
#     0.536201    0.5467138 ]]
#
#  [[-0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525  0.21098936  0.40467715  0.536201
#     0.5467138   0.60142183]]]
# 1/1 [==============================] - 0s 46ms/step
# [[[-0.11432439 -0.6187035  -0.60924554 -0.6267087  -0.6158963
#    -0.5052558  -0.43507794  0.23453276  0.50739926  0.38340738
#     0.25201595  0.2568245 ]]
#
#  [[ 0.5613537   0.4978075   0.41811967  0.33959353 -0.3799578
#    -1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036 ]]
#
#  [[ 0.4978075   0.41811967  0.33959353 -0.3799578  -1.
#    -0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211 ]]
#
#  [[ 0.41811967  0.33959353 -0.3799578  -1.         -0.9728484
#    -0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968 ]]
#
#  [[ 0.33959353 -0.3799578  -1.         -0.9728484  -0.8680903
#    -0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625]]
#
#  [[-0.3799578  -1.         -0.9728484  -0.8680903  -0.6377969
#    -0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546 ]]
#
#  [[-1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872 ]]
#
#  [[-0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941 ]]
#
#  [[-0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215 ]]
#
#  [[-0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934]]
#
#  [[-0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043 ]]
#
#  [[-0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046]]
#
#  [[-0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544 ]]
#
#  [[-0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085]]
#
#  [[-0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272]]
#
#  [[-0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349]]
#
#  [[-0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678]]
#
#  [[-0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525 ]]
#
#  [[-0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525]]
#
#  [[-0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272 -0.19108349 -0.35370678 -0.3828525
#    -0.12101525  0.21098936]]
#
#  [[-0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349 -0.35370678 -0.3828525  -0.12101525
#     0.21098936  0.40467715]]
#
#  [[-0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678 -0.3828525  -0.12101525  0.21098936
#     0.40467715  0.536201  ]]
#
#  [[ 0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525  -0.12101525  0.21098936  0.40467715
#     0.536201    0.5467138 ]]
#
#  [[-0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525  0.21098936  0.40467715  0.536201
#     0.5467138   0.60142183]]]
# 1/1 [==============================] - 0s 39ms/step
# [[[-0.6187035  -0.60924554 -0.6267087  -0.6158963  -0.5052558
#    -0.43507794  0.23453276  0.50739926  0.38340738  0.25201595
#     0.2568245   0.03339706]]
#
#  [[ 0.5613537   0.4978075   0.41811967  0.33959353 -0.3799578
#    -1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036 ]]
#
#  [[ 0.4978075   0.41811967  0.33959353 -0.3799578  -1.
#    -0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211 ]]
#
#  [[ 0.41811967  0.33959353 -0.3799578  -1.         -0.9728484
#    -0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968 ]]
#
#  [[ 0.33959353 -0.3799578  -1.         -0.9728484  -0.8680903
#    -0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625]]
#
#  [[-0.3799578  -1.         -0.9728484  -0.8680903  -0.6377969
#    -0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546 ]]
#
#  [[-1.         -0.9728484  -0.8680903  -0.6377969  -0.57598907
#    -0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872 ]]
#
#  [[-0.9728484  -0.8680903  -0.6377969  -0.57598907 -0.69253016
#    -0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941 ]]
#
#  [[-0.8680903  -0.6377969  -0.57598907 -0.69253016 -0.7186036
#    -0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215 ]]
#
#  [[-0.6377969  -0.57598907 -0.69253016 -0.7186036  -0.8503211
#    -0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934]]
#
#  [[-0.57598907 -0.69253016 -0.7186036  -0.8503211  -0.7750968
#    -0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043 ]]
#
#  [[-0.69253016 -0.7186036  -0.8503211  -0.7750968  -0.77769625
#    -0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046]]
#
#  [[-0.7186036  -0.8503211  -0.7750968  -0.77769625 -0.8419546
#    -0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544 ]]
#
#  [[-0.8503211  -0.7750968  -0.77769625 -0.8419546  -0.7639872
#    -0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085]]
#
#  [[-0.7750968  -0.77769625 -0.8419546  -0.7639872  -0.7451941
#    -0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272]]
#
#  [[-0.77769625 -0.8419546  -0.7639872  -0.7451941  -0.6609215
#    -0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349]]
#
#  [[-0.8419546  -0.7639872  -0.7451941  -0.6609215  -0.49108934
#    -0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678]]
#
#  [[-0.7639872  -0.7451941  -0.6609215  -0.49108934 -0.1488043
#     0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525 ]]
#
#  [[-0.7451941  -0.6609215  -0.49108934 -0.1488043   0.01781046
#    -0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525]]
#
#  [[-0.6609215  -0.49108934 -0.1488043   0.01781046 -0.0717544
#     0.02775085 -0.13284272 -0.19108349 -0.35370678 -0.3828525
#    -0.12101525  0.21098936]]
#
#  [[-0.49108934 -0.1488043   0.01781046 -0.0717544   0.02775085
#    -0.13284272 -0.19108349 -0.35370678 -0.3828525  -0.12101525
#     0.21098936  0.40467715]]
#
#  [[-0.1488043   0.01781046 -0.0717544   0.02775085 -0.13284272
#    -0.19108349 -0.35370678 -0.3828525  -0.12101525  0.21098936
#     0.40467715  0.536201  ]]
#
#  [[ 0.01781046 -0.0717544   0.02775085 -0.13284272 -0.19108349
#    -0.35370678 -0.3828525  -0.12101525  0.21098936  0.40467715
#     0.536201    0.5467138 ]]
#
#  [[-0.0717544   0.02775085 -0.13284272 -0.19108349 -0.35370678
#    -0.3828525  -0.12101525  0.21098936  0.40467715  0.536201
#     0.5467138   0.60142183]]]

# %%
adimen=[x for x in results]
inverted=scaler.inverse_transform(adimen)
inverted
# Out:
# array([[4108872.22313989],
#        [3411737.06742578],
#        [1991245.02150674]])

# %%
prediccion3M_FRA=pd.DataFrame(inverted)
prediccion3M_FRA.columns=["FRA Pasajeros"]
prediccion3M_FRA.plot(grid=True,
                  title="FRA - Pronostico 3 Meses",
                         ylabel="Pasajeros",
                         xlabel="Tiempo")
# Out:
# <AxesSubplot:title={'center':'FRA - Pronostico 3 Meses'}, xlabel='Tiempo', ylabel='Pasajeros'>

# %%
prediccion3M_FRA.to_csv("pronostico_FRA.csv")

# %%
df_3FRA=pd.read_csv("pronostico_FRA.csv",skip_blank_lines=True, header=0, index_col=0,na_filter=False)
df_3FRA.head()
# Out:
#    FRA Pasajeros
# 0   4.108872e+06
# 1   3.411737e+06
# 2   1.991245e+06

# %%
proyeccion=pd.concat([df,df_3FRA])

# %%
display(proyeccion)
# Out:
#                    LEJ Pasajeros  LEJ Vuelos  LEJ Carga (en Ton)  \
# 2001 - enero            100039.0      2514.0              1279.0
# 2001 - febrero          123024.0      2500.0              1282.0
# 2001 - marzo            139184.0      2828.0              1332.0
# 2001 - abril            168075.0      2853.0              1094.0
# 2001 - mayo             189075.0      2912.0              1046.0
# ...                          ...         ...                 ...
# 2022 - agosto           201995.0      6567.0            118327.0
# 2022 - septiembre       197792.0      6637.0            124579.0
# 0                            NaN         NaN                 NaN
# 1                            NaN         NaN                 NaN
# 2                            NaN         NaN                 NaN
#
#                    FRA Pasajeros  FRA Vuelos  FRA Carga (en Ton)
# 2001 - enero        3.485502e+06     36134.0            125539.0
# 2001 - febrero      3.331837e+06     33304.0            134400.0
# 2001 - marzo        4.113299e+06     37997.0            155509.0
# 2001 - abril        4.161270e+06     37103.0            133906.0
# 2001 - mayo         4.188493e+06     38321.0            128859.0
# ...                          ...         ...                 ...
# 2022 - agosto       5.184080e+06     35252.0            151582.0
# 2022 - septiembre   4.879956e+06     33529.0            157961.0
# 0                   4.108872e+06         NaN                 NaN
# 1                   3.411737e+06         NaN                 NaN
# 2                   1.991245e+06         NaN                 NaN
#
# [264 rows x 6 columns]

# %%
ax_FRA=proyeccion["FRA Pasajeros"].plot(kind="line",
                         grid=True,style="r",rot=45,
                         title="Aeropuerto de Frankfurt - Proyeccion a 3 meses",
                         ylabel="Pasajeros",
                         xlabel="Tiempo", figsize=(16,9))
df["FRA Pasajeros"].plot(secondary_y=True, style="b")
# Out:
# <AxesSubplot:>

# %%
fig=ax_FRA.get_figure()
fig.savefig(r"D:\Documents\0. PERSONAL\2. Estudio\5. Data Science\Proyecto Diplomado\FRA-3Meses_2.png")

# %% [markdown]
# ##### Fuentes

# %% [markdown]
# - [Desarrollo LEJ (hasta 2014)](https://web.archive.org/web/20150119194227/http://www.leipzig-halle-airport.de/unternehmen/ueber-uns/zahlen-und-fakten/entwicklung-158.html)
# - [Capacidad Instalada LEJ](https://www.leipzig.de/wirtschaft-und-wissenschaft/investieren-in-leipzig/infrastruktur/verkehrsinfrastruktur/flughafen-leipzighalle/)
# - [Datos](https://www.adv.aero/service/downloadbibliothek/)
# - [Reportes](https://branchenreport.bdl.aero/)
